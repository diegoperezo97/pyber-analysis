# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Create the ticks for our bar chart's x axis
plt.bar(x_axis, bars_in_cities)
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
plt.show()

# %%
# Set the limits of the x axis
plt.ylim(0, max(bars_in_cities) + 0.5)
# Out:
# (0.0, 9.1)

# %%
# Set the limits of the y axis
plt.xlim(0, len(x_axis) - 0.25)
# Out:
# (0.0, 4.75)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars")
plt.xlabel("Cities")
plt.ylabel("Bars per 10k Households")
# Out:
# Text(0, 0.5, 'Bars per 10k Households')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("/Users/diegoperezo97/Documents/Tecnológico de Monterrey – Data Analytics Boot Camp/pyber-analysis/Module 5/Monday, January 24th 2022 /5-1-Student_Resources/04-Stu_PyBars/Images/BarDensity.png")
