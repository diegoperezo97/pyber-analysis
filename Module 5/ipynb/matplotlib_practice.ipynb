# %%
# %matplotlib inline

# %%
# Import dependencies:
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import statistics
import numpy as np

# %%
# Set the x-axis to a list of strings for each month:
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month:
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis:
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
# Create the plot
plt.plot(x_axis, y_axis)
plt.xlabel("Month")
plt.ylabel("Savings ($)")
plt.title("Savings Account Results")
plt.show()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend:
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label="Boston")

# Create labels for the x and y axes:
plt.xlabel("Date")
plt.ylabel("Fare [$ USD]")

# Set the y limit between 0 and 45:
plt.ylim(0, 45)

# Create a title:
plt.title("Pyber Fare by Month")

# Add a grid:
plt.grid()

# Add legend:
plt.legend()

# %%
# Create the plot and add a label for the legend:
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label="Boston")

# Create labels for the x and y axes:
ax.set_xlabel("Date")
ax.set_ylabel("Fare [$ USD]")

# Set the y limit between 0 and 45:
ax.set_ylim(0, 45)

# Create a title:
ax.set_title("Pyber Fare by Month")

# Add a grid:
ax.grid()

# Add legend:
ax.legend()

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# Create a vertical bar chart:
plt.bar(x_axis, y_axis, color="green", label="Boston")

# Create labels for the x and y axes:
plt.xlabel("Date")
plt.ylabel("Fare [$ USD]")

# Create a title:
plt.title("PyBer Fare by Month")

# Add the legend:
plt.legend()

# %%
# Create a vertical bar chart:
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a vertical bar chart:
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create a vertical bar chart:
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a vertical bar chart:
plt.barh(x_axis, y_axis, color="m", label="Boston")
plt.gca().invert_yaxis()

# Create labels for the x and y axes:
plt.ylabel("Date")
plt.xlabel("Fare [$ USD]")

# Create a title:
plt.title("Pyber Fare by Month")

# Add legend:
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="c", label="Chicago")
ax.invert_yaxis()

# Create labels for the x and y axes:
ax.set_xlabel("Date")
ax.set_ylabel("Fare [$ USD]")

# Create a title:
ax.set_title("Pyber Fare by Month")

# Add legend:
ax.legend()

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
# Alternatively, you can use:
# ax.xaxis.set_ticks() instead of ax.set_xticks()
plt.show()

# %%
# Increase the size of the plot figure
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()

# %%
# Create a scatter plot chart with plt.scatter():
plt.plot(x_axis, y_axis, "o")

# %%
# Create a scatter plot chart with plt.scatter():
plt.scatter(y_axis, x_axis, color="r", label="Chicago")
plt.gca().invert_yaxis()

# Create labels for the x and y axes:
plt.ylabel("Date")
plt.xlabel("Fare [$ USD]")

# Create a title:
plt.title("Pyber Fare by Month")

# Add legend:
plt.legend()

# %%
# Create a bubble plot chart with plt.scatter():
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
    
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s=[i*3 for i in y_axis])

# %%
# Create a bubble plot chart using OOI method:
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# Create a bubble plot chart using OOI method:
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color="xkcd:sky blue", label="Boston", s=[i*5 for i in y_axis], alpha=0.8, edgecolors="black")
ax.invert_yaxis()

# Create labels for the x and y axes:
ax.set_ylabel("Date")
ax.set_xlabel("Fare [$ USD]")

# Create a title:
ax.set_title("Pyber Fare by Month")

# Set the y limit between 0 and 45:
ax.set_xlim(0, 50)

# Add legend:
ax.legend()

# %%
# Create a pie chart with the MATLAB method:
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
        explode=explode_values,
        colors=colors,
        labels=x_axis,
        autopct='%.1f%%')
plt.show()
